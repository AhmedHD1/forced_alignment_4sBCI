# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# all imports, numpy, scipy, matplotlib, seaborn, pandas, plotly
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import sklearn 
import os
from matplotlib import cm as colours 
from colorama import Fore, Back, Style
from scipy.stats import sem
import joblib
from scipy.stats import ttest_rel, ttest_ind
from scipy.stats import mannwhitneyu
from scipy.stats import wilcoxon
import plotly.io as pio

import sys
sys.path.insert(0, os.path.abspath('..'))
from src.utils import *

# %%
Accuracy_df_Kumar_MFA = pd.read_csv("../data/results/Accuracy_df_Kumar_MFA.csv")
# rename column name from method to Annotator 

Accuracy_df_Kumar_MFA = Accuracy_df_Kumar_MFA.rename(columns= {'Method': "Aligner"})
# change the values inside column position to make them all capital letters
Accuracy_df_Kumar_MFA['Position'] = Accuracy_df_Kumar_MFA['Position'].str.upper()
# change kumar to human 
Accuracy_df_Kumar_MFA['Aligner'] = Accuracy_df_Kumar_MFA['Aligner'].replace(['Kumar', 'MFA'], ['Manual', 'Automated'])
print(Accuracy_df_Kumar_MFA.head(20))
# print shape of the dataframe
print(Accuracy_df_Kumar_MFA.shape)
# Out:
#    Patient Position    Aligner  Accuracy
# 0      S14       P1     Manual  0.604167
# 1      S14       P1     Manual  0.576389
# 2      S14       P1     Manual  0.583333
# 3      S14       P1     Manual  0.569444
# 4      S14       P1     Manual  0.597222
# 5      S14       P1     Manual  0.576389
# 6      S14       P1     Manual  0.576389
# 7      S14       P1     Manual  0.597222
# 8      S14       P1     Manual  0.604167
# 9      S14       P1     Manual  0.611111
# 10     S14       P1  Automated  0.398649
# 11     S14       P1  Automated  0.405405
# 12     S14       P1  Automated  0.385135
# 13     S14       P1  Automated  0.398649
# 14     S14       P1  Automated  0.378378
# 15     S14       P1  Automated  0.425676
# 16     S14       P1  Automated  0.405405
# 17     S14       P1  Automated  0.385135
# 18     S14       P1  Automated  0.405405
# 19     S14       P1  Automated  0.371622
# (300, 4)

# %%
Accuracy_df_Kumar_MFA = Accuracy_df_Kumar_MFA[Accuracy_df_Kumar_MFA['Patient'] != 'S14']

patient_rename = {
    'S26': 'S1',
    'S23': 'S2',
    'S33': 'S3',
    'S22': 'S4'
}
Accuracy_df_Kumar_MFA['Patient'] = Accuracy_df_Kumar_MFA['Patient'].replace(patient_rename)
Accuracy_df_Kumar_MFA.head()
# Out:
#    Patient Position Aligner  Accuracy
# 60      S4       P1  Manual  0.185430
# 61      S4       P1  Manual  0.172185
# 62      S4       P1  Manual  0.185430
# 63      S4       P1  Manual  0.185430
# 64      S4       P1  Manual  0.132450

# %%
print(f"Number of Accuracy scores before grouping and averaging \n {Accuracy_df_Kumar_MFA.groupby(['Patient', 'Position', 'Aligner']).count().Accuracy.iloc[0]}")
Accuracy_df4stats = Accuracy_df_Kumar_MFA.groupby(['Patient', 'Position', 'Aligner'])['Accuracy'].mean().reset_index()
print(f"Number of Accuracy scores AFTER grouping and averaging \n {Accuracy_df4stats.groupby(['Patient', 'Position', 'Aligner']).count().Accuracy.iloc[0]}")

Accuracy_df_Kumar_MFA.head(len(Accuracy_df_Kumar_MFA))
# Out:
# Number of Accuracy scores before grouping and averaging
#  10
# Number of Accuracy scores AFTER grouping and averaging
#  1
#     Patient Position    Aligner  Accuracy
# 60       S4       P1     Manual  0.185430
# 61       S4       P1     Manual  0.172185
# 62       S4       P1     Manual  0.185430
# 63       S4       P1     Manual  0.185430
# 64       S4       P1     Manual  0.132450
# ..      ...      ...        ...       ...
# 295      S3       P3  Automated  0.239130
# 296      S3       P3  Automated  0.282609
# 297      S3       P3  Automated  0.217391
# 298      S3       P3  Automated  0.239130
# 299      S3       P3  Automated  0.239130
#
# [240 rows x 4 columns]

# %% [markdown]
# ## All (dist: patients), positions dropped, manual vs. auto

# %%
acc_df_kumar_mfa_pt_avg = Accuracy_df_Kumar_MFA.drop(columns=['Position']).groupby(['Patient', 'Aligner'])['Accuracy'].mean().reset_index()
print(acc_df_kumar_mfa_pt_avg)
# Out:
#   Patient    Aligner  Accuracy
# 0      S1  Automated  0.573826
# 1      S1     Manual  0.559459
# 2      S2  Automated  0.240260
# 3      S2     Manual  0.265784
# 4      S3  Automated  0.352899
# 5      S3     Manual  0.352174
# 6      S4  Automated  0.261623
# 7      S4     Manual  0.216998

# %%
import plotly.express as px

# Base color mapping for aligners
colorsmap = {
    'Manual': px.colors.qualitative.Vivid[1],
    'Automated': px.colors.qualitative.Vivid[0]
}

# Use a completely different palette for patients
patient_colors = px.colors.qualitative.Dark24 
patients = acc_df_kumar_mfa_pt_avg["Patient"].unique()
patient_color_map = {
    patient: patient_colors[i % len(patient_colors)]
    for i, patient in enumerate(patients)
}

# --- Patient lines (colored uniquely) ---
fig = px.line(
    acc_df_kumar_mfa_pt_avg,
    x='Aligner',
    y='Accuracy',
    color='Patient',
    color_discrete_map=patient_color_map
)

# --- Overlay boxplots (aligner colors unchanged) ---
boxplt = px.box(
    acc_df_kumar_mfa_pt_avg,
    x='Aligner',
    y='Accuracy',
    color='Aligner',
    color_discrete_sequence=px.colors.qualitative.Vivid,
    color_discrete_map=colorsmap
)
fig.add_traces(boxplt.data)

# --- Chance line ---
fig.add_hline(
    y=1/9,
    line_dash='dash',
    line_color='gray',
    annotation_text='Chance',
    annotation_position='bottom right'
)

# --- Layout ---
fig.update_layout(
    plot_bgcolor='white',
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=0.02,
        xanchor='left',
        x=0.01,
        title_text=''
    ),
    margin=dict(l=35, r=8, t=15, b=40),
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
)
fig.update_xaxes(
    title='',
    mirror=False,
    ticks='outside',
    showline=True,
    linecolor='black',
    showgrid=False,
    autorange='reversed'
)
fig.update_yaxes(
    title='Phoneme decoding accuracy',
    mirror=False,
    ticks='outside',
    showline=True,
    linecolor='black',
    showgrid=False,
    rangemode='tozero'
)
save_svg(fig, "../figures/figure4/manualvsautomated_DecodingAcc_linedashedbyPatients5.svg",
         **PANEL_DIMS['figure4']['line_by_patient'])
fig.show()

# %%
kumar_array = acc_df_kumar_mfa_pt_avg[acc_df_kumar_mfa_pt_avg['Aligner'] == 'Manual']['Accuracy']
mfa_array = acc_df_kumar_mfa_pt_avg[acc_df_kumar_mfa_pt_avg['Aligner'] == 'Automated']['Accuracy']
result = wilcoxon(kumar_array, mfa_array)
print(result)
print("***: p < 0.001\n** : p < 0.01\n*  : p < 0.05\nn.s.: p > 0.05")
# Out:
# WilcoxonResult(statistic=np.float64(3.0), pvalue=np.float64(0.625))
# ***: p < 0.001
# ** : p < 0.01
# *  : p < 0.05
# n.s.: p > 0.05

# %% [markdown]
# ## Here we do across positions, with dist being patients, averaged across iterations

# %%
acc_df_kumar_mfa_pos_avgiter = Accuracy_df_Kumar_MFA.groupby(['Patient', 'Position', 'Aligner'])['Accuracy'].mean().reset_index()
print(acc_df_kumar_mfa_pos_avgiter)
# Out:
#    Patient Position    Aligner  Accuracy
# 0       S1       P1  Automated  0.602013
# 1       S1       P1     Manual  0.597973
# 2       S1       P2  Automated  0.552349
# 3       S1       P2     Manual  0.560811
# 4       S1       P3  Automated  0.567114
# 5       S1       P3     Manual  0.519595
# 6       S2       P1  Automated  0.268182
# 7       S2       P1     Manual  0.267550
# 8       S2       P2  Automated  0.264286
# 9       S2       P2     Manual  0.293377
# 10      S2       P3  Automated  0.188312
# 11      S2       P3     Manual  0.236424
# 12      S3       P1  Automated  0.469565
# 13      S3       P1     Manual  0.480435
# 14      S3       P2  Automated  0.317391
# 15      S3       P2     Manual  0.280435
# 16      S3       P3  Automated  0.271739
# 17      S3       P3     Manual  0.295652
# 18      S4       P1  Automated  0.210526
# 19      S4       P1     Manual  0.166225
# 20      S4       P2  Automated  0.330263
# 21      S4       P2     Manual  0.323841
# 22      S4       P3  Automated  0.244079
# 23      S4       P3     Manual  0.160927

# %%
for pos in acc_df_kumar_mfa_pos_avgiter['Position'].unique():
    print(pos)
    kumar_array = acc_df_kumar_mfa_pos_avgiter[
        (acc_df_kumar_mfa_pos_avgiter['Aligner'] == 'Manual') & 
        (acc_df_kumar_mfa_pos_avgiter['Position'] == pos)]
    mfa_array = acc_df_kumar_mfa_pos_avgiter[
        (acc_df_kumar_mfa_pos_avgiter['Aligner'] == 'Automated') & 
        (acc_df_kumar_mfa_pos_avgiter['Position'] == pos)]
    # check if patient order is the same in both arrays
    # if not, print warning
    if not all(kumar_array['Patient'].values == mfa_array['Patient'].values):
        print("Warning: Patient order mismatch between Kumar and MFA arrays")    
    result = wilcoxon(kumar_array['Accuracy'], mfa_array['Accuracy'])
    #print(kumar_array)
    #print("-"*10)
    #print(mfa_array)
    print("wilcoxon result:")
    print(result)
# Out:
# P1
# wilcoxon result:
# WilcoxonResult(statistic=np.float64(3.0), pvalue=np.float64(0.625))
# P2
# wilcoxon result:
# WilcoxonResult(statistic=np.float64(5.0), pvalue=np.float64(1.0))
# P3
# wilcoxon result:
# WilcoxonResult(statistic=np.float64(4.0), pvalue=np.float64(0.875))

# %%
colorsmap = {
    'Manual': px.colors.qualitative.Vivid[1],
    'Automated': px.colors.qualitative.Vivid[0]
}
fig = px.box(acc_df_kumar_mfa_pos_avgiter,
    y='Accuracy',
    x='Position',
    color='Aligner',
    points='all',  # Shows stripplot-like points
    boxmode='group',
    hover_name='Patient',
    hover_data=['Patient', 'Accuracy', 'Position'],
    color_discrete_sequence= px.colors.qualitative.Vivid, 
    color_discrete_map= colorsmap,
    category_orders={"Aligner":['Manual', 'Automated']}     
    )
fig.update_traces(marker=dict(size=5,opacity=0.9), jitter=0.3, boxmean=True)

fig.add_hline(
    y=1/9,
    line_dash='dash',
    line_color='gray',
    annotation_text='Chance',
    annotation_position='bottom right'
)

fig.update_yaxes(rangemode="tozero", showline=True, linecolor="black", linewidth=2, ticks='outside')
fig.update_xaxes(showline=True, linecolor="black", linewidth=2, ticks='outside')
fig.update_layout(
    plot_bgcolor='white',
    legend=None,
    title_text='',
    title_x=0.5,
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
    margin=dict(l=35, r=8, t=15, b=40)
)
save_svg(fig, "../figures/figure4/manualvsautomated_DecodingAccByPosPlotlyavgd5.svg",
         **PANEL_DIMS['figure4']['by_position'])
fig.show()

# %%
diffb = 17.062 - 24.203
diffa = 18.201 - 25.119 
print(diffb, diffa) 

# w = 0.871, h = 0.987
# Out:
# -7.140999999999998 -6.917999999999999

# %% [markdown]
# ## Here we do per patient, distributions being iterations, and we average across positions cuz who cares about their effect on patient/method

# %%
acc_df_kumar_mfa_iter_avgpos = Accuracy_df_Kumar_MFA.sort_values(
    ['Patient', 'Aligner', 'Position']
).reset_index(drop=True)

# create iteration index (0â€“9 for each patientÃ—methodÃ—position)
acc_df_kumar_mfa_iter_avgpos['Iteration'] = (
    acc_df_kumar_mfa_iter_avgpos.groupby(['Patient', 'Aligner', 'Position']).cumcount()
)

# average across positions, keeping 10 iterations per patientÃ—method
acc_df_kumar_mfa_iter_avgpos = (
    acc_df_kumar_mfa_iter_avgpos.drop(columns=['Position'])
    .groupby(['Patient', 'Aligner', 'Iteration'], as_index=False)['Accuracy']
    .mean()
)

acc_df_kumar_mfa_iter_avgpos.head()
# Out:
#   Patient    Aligner  Iteration  Accuracy
# 0      S1  Automated          0  0.577181
# 1      S1  Automated          1  0.563758
# 2      S1  Automated          2  0.572707
# 3      S1  Automated          3  0.570470
# 4      S1  Automated          4  0.577181

# %%
mean1, mean2 = acc_df_kumar_mfa_iter_avgpos[
        (acc_df_kumar_mfa_iter_avgpos['Aligner'] == 'Manual') & 
        (acc_df_kumar_mfa_iter_avgpos['Patient'] == 'S1')]['Accuracy'].mean() , acc_df_kumar_mfa_iter_avgpos[
        (acc_df_kumar_mfa_iter_avgpos['Aligner'] == 'Automated') & 
        (acc_df_kumar_mfa_iter_avgpos['Patient'] == 'S1')]['Accuracy'].mean()
        
print(mean1, mean2)
# Out:
# 0.5594594594594595 0.5738255033557047

# %%
for pat in acc_df_kumar_mfa_iter_avgpos['Patient'].unique():
    print(pat)
    kumar_array = acc_df_kumar_mfa_iter_avgpos[
        (acc_df_kumar_mfa_iter_avgpos['Aligner'] == 'Manual') & 
        (acc_df_kumar_mfa_iter_avgpos['Patient'] == pat)]['Accuracy']
    mfa_array = acc_df_kumar_mfa_iter_avgpos[
        (acc_df_kumar_mfa_iter_avgpos['Aligner'] == 'Automated') & 
        (acc_df_kumar_mfa_iter_avgpos['Patient'] == pat)]['Accuracy']    
    result = mannwhitneyu(kumar_array, mfa_array)
    print(result)
# Out:
# S1
# MannwhitneyuResult(statistic=np.float64(3.0), pvalue=np.float64(0.000418144432661332))
# S2
# MannwhitneyuResult(statistic=np.float64(98.0), pvalue=np.float64(0.00031970214768035134))
# S3
# MannwhitneyuResult(statistic=np.float64(48.5), pvalue=np.float64(0.9393087523212691))
# S4
# MannwhitneyuResult(statistic=np.float64(0.0), pvalue=np.float64(0.0001746242085521927))

# %%
orderforplot = {
    "Difference_Variable": ['Onset', 'Offset', 'Duration'], 
    "Phoneme": ['a', 'ae', 'b', 'g', 'i', 'k', 'p', 'u', 'v'], 
    "Patient": ['S1', 'S2', 'S3', 'S4', 'S5'], 
    "Aligner":['Manual', 'Automated']
    
}

colorsmap = {
    'Manual': px.colors.qualitative.Vivid[1],
    'Automated': px.colors.qualitative.Vivid[0]
}
fig = px.box(acc_df_kumar_mfa_iter_avgpos,
    y='Accuracy',
    x='Patient',
    color='Aligner',
    points='all',  # Shows stripplot-like points
    boxmode='group', 
    hover_data=['Patient', 'Aligner', 'Accuracy', 'Iteration'],
    color_discrete_sequence= px.colors.qualitative.Vivid, 
    color_discrete_map= colorsmap, 
    category_orders=orderforplot
    )
fig.update_traces(jitter=0.3)
fig.add_hline(
    y=1/9,
    line_dash='dash',
    line_color='gray',
    annotation_text='Chance',
    annotation_position='bottom right'
)
fig.update_yaxes(rangemode="tozero", showline=True, linecolor="black", linewidth=2, ticks='outside')
fig.update_xaxes(showline=True, linecolor="black", linewidth=2, ticks='outside')
fig.update_layout(
    plot_bgcolor='white',
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=0.02,
        xanchor='left',
        x=0.01,
        title_text=''
    ),
    title_text='',
    title_x=0.5,
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
    margin=dict(l=35, r=8, t=15, b=40)
)
save_svg(fig, "../figures/figure4/manualvsautomated_DecodingAccByPatPlotlyavgd5.svg",
         **PANEL_DIMS['figure4']['by_patient'])
fig.show()

# %% [markdown]
# # Decoding TW Analyses

# %%
Accuracy_DWs = pd.read_csv("../data/results/decoding_accuracy_varying_dw.csv")
Accuracy_DWs.head(20)
# Out:
#     Unnamed: 0 Patient Position Method Decoding TW  Accuracy
# 0            0     S14       p1  Kumar          1S  0.604167
# 1            1     S14       p1  Kumar          1S  0.597222
# 2            2     S14       p1  Kumar          1S  0.604167
# 3            3     S14       p1  Kumar          1S  0.590278
# 4            4     S14       p1  Kumar          1S  0.604167
# 5            5     S14       p1  Kumar          1S  0.576389
# 6            6     S14       p1  Kumar          1S  0.583333
# 7            7     S14       p1  Kumar          1S  0.611111
# 8            8     S14       p1  Kumar          1S  0.590278
# 9            9     S14       p1  Kumar          1S  0.555556
# 10          10     S14       p1  Kumar        0.8S  0.541667
# 11          11     S14       p1  Kumar        0.8S  0.576389
# 12          12     S14       p1  Kumar        0.8S  0.569444
# 13          13     S14       p1  Kumar        0.8S  0.562500
# 14          14     S14       p1  Kumar        0.8S  0.555556
# 15          15     S14       p1  Kumar        0.8S  0.548611
# 16          16     S14       p1  Kumar        0.8S  0.555556
# 17          17     S14       p1  Kumar        0.8S  0.555556
# 18          18     S14       p1  Kumar        0.8S  0.590278
# 19          19     S14       p1  Kumar        0.8S  0.590278

# %%
display(Accuracy_DWs['Decoding TW'].unique()[::-1])
# Out:
# array(['0.01S', '0.015S', '0.025S', '0.05S', '0.1S', '0.2S', '0.4S',
#        '0.6S', '0.8S', '1S'], dtype=object)

# %%
Accuracy_DWs = Accuracy_DWs[~Accuracy_DWs['Decoding TW'].isin(['0.015S', '0.025S', '0.05S'])]
display(Accuracy_DWs['Decoding TW'].unique())
# Out:
# array(['1S', '0.8S', '0.6S', '0.4S', '0.2S', '0.1S', '0.01S'],
#       dtype=object)

# %%
Accuracy_DWs = Accuracy_DWs.rename(columns= {'Method': "Aligner"})
# change the values inside column position to make them all capital letters
Accuracy_DWs['Position'] = Accuracy_DWs['Position'].str.upper()
# change kumar to human 
Accuracy_DWs['Aligner'] = Accuracy_DWs['Aligner'].replace(['Kumar', 'MFA'], ['Manual', 'Automated'])

Accuracy_DWs = Accuracy_DWs[Accuracy_DWs['Patient'] != 'S14']

patient_rename = {
    'S26': 'S1',
    'S23': 'S2',
    'S33': 'S3',
    'S22': 'S4'
}
Accuracy_DWs['Patient'] = Accuracy_DWs['Patient'].replace(patient_rename)
print(Accuracy_DWs.shape)
Accuracy_DWs.head()
# Out:
# (1680, 6)
#      Unnamed: 0 Patient Position Aligner Decoding TW  Accuracy
# 300         300      S4       P1  Manual          1S  0.158940
# 301         301      S4       P1  Manual          1S  0.178808
# 302         302      S4       P1  Manual          1S  0.152318
# 303         303      S4       P1  Manual          1S  0.132450
# 304         304      S4       P1  Manual          1S  0.185430

# %%
print(f"Number of Accuracy scores before grouping and averaging \n {Accuracy_DWs.drop(columns=['Position']).groupby(['Patient', 'Aligner', 'Decoding TW']).count().Accuracy.iloc[0]}")
Accuracy_df4statsdw = Accuracy_DWs.drop(columns=['Position']).groupby(['Patient', 'Aligner', 'Decoding TW'])['Accuracy'].mean().reset_index()
print(f"Number of Accuracy scores AFTER grouping and averaging \n {Accuracy_df4statsdw.groupby(['Patient', 'Aligner', 'Decoding TW']).count().Accuracy.iloc[0]}")

Accuracy_df4statsdw.head(len(Accuracy_df4statsdw))
# Out:
# Number of Accuracy scores before grouping and averaging
#  30
# Number of Accuracy scores AFTER grouping and averaging
#  1
#    Patient    Aligner Decoding TW  Accuracy
# 0       S1  Automated       0.01S  0.319239
# 1       S1  Automated        0.1S  0.379642
# 2       S1  Automated        0.2S  0.443848
# 3       S1  Automated        0.4S  0.514765
# 4       S1  Automated        0.6S  0.562416
# 5       S1  Automated        0.8S  0.564430
# 6       S1  Automated          1S  0.579418
# 7       S1     Manual       0.01S  0.308784
# 8       S1     Manual        0.1S  0.397523
# 9       S1     Manual        0.2S  0.440541
# 10      S1     Manual        0.4S  0.511261
# 11      S1     Manual        0.6S  0.539640
# 12      S1     Manual        0.8S  0.559009
# 13      S1     Manual          1S  0.561486
# 14      S2  Automated       0.01S  0.173810
# 15      S2  Automated        0.1S  0.169048
# 16      S2  Automated        0.2S  0.193290
# 17      S2  Automated        0.4S  0.246537
# 18      S2  Automated        0.6S  0.251082
# 19      S2  Automated        0.8S  0.238528
# 20      S2  Automated          1S  0.241558
# 21      S2     Manual       0.01S  0.177704
# 22      S2     Manual        0.1S  0.206843
# 23      S2     Manual        0.2S  0.205740
# 24      S2     Manual        0.4S  0.258940
# 25      S2     Manual        0.6S  0.262914
# 26      S2     Manual        0.8S  0.277704
# 27      S2     Manual          1S  0.273068
# 28      S3  Automated       0.01S  0.255072
# 29      S3  Automated        0.1S  0.293478
# 30      S3  Automated        0.2S  0.355797
# 31      S3  Automated        0.4S  0.376812
# 32      S3  Automated        0.6S  0.379710
# 33      S3  Automated        0.8S  0.381159
# 34      S3  Automated          1S  0.347101
# 35      S3     Manual       0.01S  0.288406
# 36      S3     Manual        0.1S  0.280435
# 37      S3     Manual        0.2S  0.328986
# 38      S3     Manual        0.4S  0.357971
# 39      S3     Manual        0.6S  0.407246
# 40      S3     Manual        0.8S  0.384058
# 41      S3     Manual          1S  0.330435
# 42      S4  Automated       0.01S  0.173684
# 43      S4  Automated        0.1S  0.180482
# 44      S4  Automated        0.2S  0.190351
# 45      S4  Automated        0.4S  0.191009
# 46      S4  Automated        0.6S  0.227193
# 47      S4  Automated        0.8S  0.254386
# 48      S4  Automated          1S  0.260746
# 49      S4     Manual       0.01S  0.177263
# 50      S4     Manual        0.1S  0.188521
# 51      S4     Manual        0.2S  0.199117
# 52      S4     Manual        0.4S  0.170419
# 53      S4     Manual        0.6S  0.187859
# 54      S4     Manual        0.8S  0.185430
# 55      S4     Manual          1S  0.211258

# %%
for dw in Accuracy_df4statsdw['Decoding TW'].unique():
    print(dw)
    kumar_array = Accuracy_df4statsdw[
        (Accuracy_df4statsdw['Aligner'] == 'Manual') & 
        (Accuracy_df4statsdw['Decoding TW'] == dw)]['Accuracy']
    mfa_array = Accuracy_df4statsdw[
        (Accuracy_df4statsdw['Aligner'] == 'Automated') & 
        (Accuracy_df4statsdw['Decoding TW'] == dw)]['Accuracy']    
    result = wilcoxon(kumar_array, mfa_array)
    print(result)
# Out:
# 0.01S
# WilcoxonResult(statistic=np.float64(3.0), pvalue=np.float64(0.625))
# 0.1S
# WilcoxonResult(statistic=np.float64(2.0), pvalue=np.float64(0.375))
# 0.2S
# WilcoxonResult(statistic=np.float64(5.0), pvalue=np.float64(1.0))
# 0.4S
# WilcoxonResult(statistic=np.float64(2.0), pvalue=np.float64(0.375))
# 0.6S
# WilcoxonResult(statistic=np.float64(4.0), pvalue=np.float64(0.875))
# 0.8S
# WilcoxonResult(statistic=np.float64(4.0), pvalue=np.float64(0.875))
# 1S
# WilcoxonResult(statistic=np.float64(3.0), pvalue=np.float64(0.625))

# %% [markdown]
# # General Trend for DWs

# %%
per_patient = Accuracy_df4statsdw.groupby(
    ["Aligner", "Decoding TW", "Patient"], as_index=False
)["Accuracy"].mean()

summary = per_patient.groupby(
    ["Aligner", "Decoding TW"], as_index=False
).agg(
    mean_acc=("Accuracy", "mean"),
    sd=("Accuracy", "std"),
    n=("Accuracy", "count")
)

tw_map = {
    "1S": 1.0,
    "0.8S": 0.8,
    "0.6S": 0.6,
    "0.4S": 0.4,
    "0.2S": 0.2, 
    "0.1S": 0.1, 
    "0.01S": 0.01
}
summary["TW_value"] = summary["Decoding TW"].map(tw_map)

summary["sem"] = summary["sd"] / np.sqrt(summary["n"])
summary["upper"] = summary["mean_acc"] + summary["sem"]
summary["lower"] = summary["mean_acc"] - summary["sem"]

aligners_to_plot = ["Manual", "Automated"]
df_plot = summary

fig = go.Figure()

for aligner in aligners_to_plot:
    df_a = df_plot[df_plot["Aligner"] == aligner].sort_values("TW_value")
    color = colorsmap[aligner]

    fig.add_trace(
        go.Scatter(
            x=pd.concat([df_a["TW_value"], df_a["TW_value"][::-1]]),
            y=pd.concat([df_a["upper"], df_a["lower"][::-1]]),
            fill='toself',
            fillcolor=color.replace("rgb", "rgba").replace(")", ",0.2)"),  
            line=dict(color='rgba(255,255,255,0)'),
            hoverinfo="skip",
            showlegend=False
        )
    )
    
    fig.add_trace(
        go.Scatter(
            x=df_a["TW_value"],
            y=df_a["mean_acc"],
            mode="lines+markers",
            name=aligner,
            line=dict(width=2, color=color)
        )
    )

fig.add_hline(
    y=1/9,
    line_dash="dash",
    line_color="red",
    annotation_text="Chance",
    annotation_position="bottom right"
)

fig.update_yaxes(
    title="Decoding Accuracy",
    rangemode="tozero",
    showline=True, linecolor="black", linewidth=2, ticks="outside"
)
fig.update_xaxes(
    type = 'log',
    title="Decoding TW",
    tickvals=list(tw_map.values()),
    ticktext=list(tw_map.keys()),
    showline=True, linecolor="black", linewidth=2, ticks="outside"
)
fig.update_layout(
    plot_bgcolor='white',
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=0.02,
        xanchor='left',
        x=0.01,
        title_text=''
    ),
    title_text='',
    title_x=0.5,
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family'])
)
#fig.write_image("../figures/figure4/manualvsautomated_DecodingAccByDTWLinePlot3.pdf", format="pdf")

fig.show()

# %% [markdown]
# # Same but per patient (more separation between patients)

# %%
tw_mapms = {
    '1S': '1000',
    '0.8S': '800',
    '0.6S': '600',
    '0.4S': '400',
    '0.2S': '200',
    '0.1S': '100',
    '0.01S': '10'
    }

# %%
Accuracy_df4statsdw.head()
# Out:
#   Patient    Aligner Decoding TW  Accuracy
# 0      S1  Automated       0.01S  0.319239
# 1      S1  Automated        0.1S  0.379642
# 2      S1  Automated        0.2S  0.443848
# 3      S1  Automated        0.4S  0.514765
# 4      S1  Automated        0.6S  0.562416

# %%
for pat in Accuracy_df4statsdw.Patient.unique():
    print(pat)
    for dw in Accuracy_df4statsdw['Decoding TW'].unique():
        print(dw)
        kumar_array = Accuracy_df4statsdw[
            (Accuracy_df4statsdw['Aligner'] == 'Manual') & 
            (Accuracy_df4statsdw['Decoding TW'] == dw) &
            (Accuracy_df4statsdw['Patient'] == pat)
            ]['Accuracy']
        mfa_array = Accuracy_df4statsdw[
            (Accuracy_df4statsdw['Aligner'] == 'Automated') & 
            (Accuracy_df4statsdw['Decoding TW'] == dw) &
            (Accuracy_df4statsdw['Patient'] == pat)]['Accuracy'] 
        print(kumar_array)
        print(mfa_array)   
        result = wilcoxon(kumar_array, mfa_array)
        print(result)
        
# actually there is no distribution... makes sense why pvalue is 1
# Out:
# S1
# 0.01S
# 7    0.308784
# Name: Accuracy, dtype: float64
# 0    0.319239
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.1S
# 8    0.397523
# Name: Accuracy, dtype: float64
# 1    0.379642
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.2S
# 9    0.440541
# Name: Accuracy, dtype: float64
# 2    0.443848
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.4S
# 10    0.511261
# Name: Accuracy, dtype: float64
# 3    0.514765
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.6S
# 11    0.53964
# Name: Accuracy, dtype: float64
# 4    0.562416
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.8S
# 12    0.559009
# Name: Accuracy, dtype: float64
# 5    0.56443
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 1S
# 13    0.561486
# Name: Accuracy, dtype: float64
# 6    0.579418
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# S2
# 0.01S
# 21    0.177704
# Name: Accuracy, dtype: float64
# 14    0.17381
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.1S
# 22    0.206843
# Name: Accuracy, dtype: float64
# 15    0.169048
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.2S
# 23    0.20574
# Name: Accuracy, dtype: float64
# 16    0.19329
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.4S
# 24    0.25894
# Name: Accuracy, dtype: float64
# 17    0.246537
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.6S
# 25    0.262914
# Name: Accuracy, dtype: float64
# 18    0.251082
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.8S
# 26    0.277704
# Name: Accuracy, dtype: float64
# 19    0.238528
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 1S
# 27    0.273068
# Name: Accuracy, dtype: float64
# 20    0.241558
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# S3
# 0.01S
# 35    0.288406
# Name: Accuracy, dtype: float64
# 28    0.255072
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.1S
# 36    0.280435
# Name: Accuracy, dtype: float64
# 29    0.293478
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.2S
# 37    0.328986
# Name: Accuracy, dtype: float64
# 30    0.355797
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.4S
# 38    0.357971
# Name: Accuracy, dtype: float64
# 31    0.376812
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.6S
# 39    0.407246
# Name: Accuracy, dtype: float64
# 32    0.37971
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.8S
# 40    0.384058
# Name: Accuracy, dtype: float64
# 33    0.381159
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 1S
# 41    0.330435
# Name: Accuracy, dtype: float64
# 34    0.347101
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# S4
# 0.01S
# 49    0.177263
# Name: Accuracy, dtype: float64
# 42    0.173684
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.1S
# 50    0.188521
# Name: Accuracy, dtype: float64
# 43    0.180482
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.2S
# 51    0.199117
# Name: Accuracy, dtype: float64
# 44    0.190351
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.4S
# 52    0.170419
# Name: Accuracy, dtype: float64
# 45    0.191009
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.6S
# 53    0.187859
# Name: Accuracy, dtype: float64
# 46    0.227193
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 0.8S
# 54    0.18543
# Name: Accuracy, dtype: float64
# 47    0.254386
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))
# 1S
# 55    0.211258
# Name: Accuracy, dtype: float64
# 48    0.260746
# Name: Accuracy, dtype: float64
# WilcoxonResult(statistic=np.float64(0.0), pvalue=np.float64(1.0))

# %%
import plotly.graph_objects as go

# Prepare data: one line per patient Ã— aligner
df_plot = per_patient.copy()
df_plot["TW_value"] = df_plot["Decoding TW"].map(tw_map)

fig = go.Figure()

# assign each patient a dash style
dash_styles = ["longdash", "dash", "dashdot", "dot", "longdashdot"]
patients = df_plot["Patient"].unique()
patient_dash_map = {
    patient: dash_styles[i % len(dash_styles)] for i, patient in enumerate(patients)
}

# Real traces (hidden from legend)
for patient in patients:
    for aligner in ["Manual", "Automated"]:
        df_sub = df_plot[(df_plot["Patient"] == patient) & (df_plot["Aligner"] == aligner)]
        df_sub = df_sub.sort_values("TW_value")
        
        fig.add_trace(
            go.Scatter(
                x=df_sub["TW_value"],
                y=df_sub["Accuracy"],
                mode="lines+markers",
                name=f"{aligner} - P{patient}",
                line=dict(
                    color=colorsmap[aligner],
                    dash=patient_dash_map[patient],
                    width=2
                ),
                showlegend=False
            )
        )

# Dummy traces for legend: aligners (color only)
for aligner in ["Manual", "Automated"]:
    fig.add_trace(
        go.Scatter(
            x=[None], y=[None],
            mode="lines",
            line=dict(color=colorsmap[aligner], width=2),
            name=aligner,
        )
    )

# Dummy traces for legend: patients (dash only, neutral color)
for patient in patients:
    fig.add_trace(
        go.Scatter(
            x=[None], y=[None],
            mode="lines",
            line=dict(color="gray", dash=patient_dash_map[patient], width=2),
            name=f"{patient}"
        )
    )

# Chance line
fig.add_hline(
    y=1/9,
    line_dash="dash",
    line_color="gray",
    annotation_text="Chance",
    annotation_position="bottom right"
)

# Axes formatting
fig.update_yaxes(
    title="Decoding Accuracy",
    rangemode="tozero",
    showline=True, linecolor="black", linewidth=1, ticks="outside",
    tickfont=dict(size=PLOT_STYLE['font']['size_tick']), title_font=dict(size=PLOT_STYLE['font']['size_label'])
)
fig.update_xaxes(
    title="Decoding TW",
    tickvals=list(tw_map.values()),
    ticktext=list(tw_mapms.values()),
    tickfont=dict(size=PLOT_STYLE['font']['size_tick']),
    title_font=dict(size=PLOT_STYLE['font']['size_label']),
    automargin=True,
    showline=True, linecolor="black", linewidth=1, ticks="outside"
)
fig.update_layout(
    plot_bgcolor='white',
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=0.02,
        xanchor='left',
        x=0.01,
        title_text=''
    ),
    title_text='',
    title_x=0.5,
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
    margin=dict(l=35, r=8, t=15, b=40),
)

save_svg(fig, "../figures/figure4/manualvsautomated_DecodingAccByDTWLinePlotbypat5.svg",
         **PANEL_DIMS['figure4']['dtw_line'])
fig.show()

# %%
import plotly.graph_objects as go

# Prepare data: one line per patient Ã— aligner
df_plot = per_patient.copy()
df_plot["TW_value"] = df_plot["Decoding TW"].map(tw_map)

fig = go.Figure()

# assign each patient a dash style and marker
dash_styles = ["longdash", "dash", "dashdot", "dot", "longdashdot"]
marker_styles = ["circle", "square", "diamond", "cross", "triangle-up"]
patients = df_plot["Patient"].unique()
patient_dash_map = {
    patient: dash_styles[i % len(dash_styles)] for i, patient in enumerate(patients)
}
patient_marker_map = {
    patient: marker_styles[i % len(marker_styles)] for i, patient in enumerate(patients)
}

# Real traces (hidden from legend)
for patient in patients:
    for aligner in ["Manual", "Automated"]:
        df_sub = df_plot[(df_plot["Patient"] == patient) & (df_plot["Aligner"] == aligner)]
        df_sub = df_sub.sort_values("TW_value")

        fig.add_trace(
            go.Scatter(
                x=df_sub["TW_value"],
                y=df_sub["Accuracy"],
                mode="lines+markers",
                name=f"{aligner} - P{patient}",
                line=dict(
                    color=colorsmap[aligner],
                    dash=patient_dash_map[patient],
                    width=2
                ),
                marker=dict(
                    symbol=patient_marker_map[patient],
                    size=8,
                    color=colorsmap[aligner]
                ),
                showlegend=False
            )
        )

# Dummy traces for legend: aligners (color only)
for aligner in ["Manual", "Automated"]:
    fig.add_trace(
        go.Scatter(
            x=[None], y=[None],
            mode="lines",
            line=dict(color=colorsmap[aligner], width=2),
            name=aligner,
        )
    )

# Dummy traces for legend: patients (dash + marker, neutral color)
for patient in patients:
    fig.add_trace(
        go.Scatter(
            x=[None], y=[None],
            mode="lines+markers",
            line=dict(color="gray", dash=patient_dash_map[patient], width=2),
            marker=dict(symbol=patient_marker_map[patient], size=8, color="gray"),
            name=f"{patient}"
        )
    )

# Chance line
fig.add_hline(
    y=1/9,
    line_dash="dash",
    line_color="gray",
    annotation_text="Chance",
    annotation_position="bottom right"
)

# Axes formatting
fig.update_yaxes(
    title="Decoding Accuracy",
    rangemode="tozero",
    showline=True, linecolor="black", linewidth=1, ticks="outside",
    tickfont=dict(size=PLOT_STYLE['font']['size_tick']), title_font=dict(size=PLOT_STYLE['font']['size_label'])
)
fig.update_xaxes(
    title="Decoding TW",
    tickvals=list(tw_map.values()),
    ticktext=list(tw_mapms.values()),
    tickfont=dict(size=PLOT_STYLE['font']['size_tick']),
    title_font=dict(size=PLOT_STYLE['font']['size_label']),
    automargin=True,
    showline=True, linecolor="black", linewidth=1, ticks="outside"
)
fig.update_layout(
    plot_bgcolor='white',
    legend=dict(
        orientation='h',
        yanchor='bottom',
        y=0.02,
        xanchor='left',
        x=0.01,
        title_text=''
    ),
    title_text='',
    title_x=0.5,
    font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
    margin=dict(l=35, r=8, t=15, b=40)
)

# fig.write_image(
#     "../figures/figure4/manualvsautomated_DecodingAccByDTWLinePlotbypat5.svg",
#     width=780,
#     height=543
# )

fig.show()

# %%
SVG_PATH = "../figures/figure4/manualvsautomated_DecodingAccByDTWLinePlotbypat5_new.svg"
save_svg(fig, SVG_PATH, **PANEL_DIMS['figure4']['dtw_line'])

# %%
# â”€â”€ Full Figure 4 assembly â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€â”€
# Layout: 2 rows Ã— 2 cols
#   Row 1: [P1 all patients line+box]  [P2 by patient box]
#   Row 2: [P3 by position box]        [P4 DTW line by patient]
#
# All data frames (acc_df_kumar_mfa_pt_avg, acc_df_kumar_mfa_iter_avgpos,
# acc_df_kumar_mfa_pos_avgiter, per_patient, tw_map, colorsmap) are already
# in scope from the cells above.

# --- Panel 1: all patients, line + box overlay ---
_pcolors = px.colors.qualitative.Dark24
_pts     = acc_df_kumar_mfa_pt_avg["Patient"].unique()
_pcmap   = {p: _pcolors[i % len(_pcolors)] for i, p in enumerate(_pts)}

fig4_p1 = px.line(acc_df_kumar_mfa_pt_avg, x='Aligner', y='Accuracy',
                  color='Patient', color_discrete_map=_pcmap)
fig4_p1.add_traces(
    px.box(acc_df_kumar_mfa_pt_avg, x='Aligner', y='Accuracy',
           color='Aligner', color_discrete_map=colorsmap).data)
fig4_p1.add_hline(y=1/9, line_dash='dash', line_color='gray',
                  annotation_text='Chance', annotation_position='bottom right')
fig4_p1.update_layout(plot_bgcolor='white', font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
                      legend=dict(orientation='h', y=0.02, x=0.01, title_text=''),
                      margin=dict(l=35, r=8, t=15, b=40))
fig4_p1.update_xaxes(showline=True, linecolor='black', ticks='outside',
                     showgrid=False, autorange='reversed', title='')
fig4_p1.update_yaxes(title='Phoneme decoding accuracy', showline=True,
                     linecolor='black', ticks='outside', showgrid=False, rangemode='tozero')

# --- Panel 2: by patient, box ---
fig4_p2 = px.box(acc_df_kumar_mfa_iter_avgpos, y='Accuracy', x='Patient',
                 color='Aligner', points='all', boxmode='group',
                 color_discrete_map=colorsmap,
                 category_orders={"Aligner": ['Manual', 'Automated'],
                                  "Patient": ['S1', 'S2', 'S3', 'S4']})
fig4_p2.update_traces(jitter=0.3)
fig4_p2.add_hline(y=1/9, line_dash='dash', line_color='gray',
                  annotation_text='Chance', annotation_position='bottom right')
fig4_p2.update_layout(plot_bgcolor='white', font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
                      legend=dict(orientation='h', y=0.02, x=0.01, title_text=''),
                      margin=dict(l=35, r=8, t=15, b=40))
fig4_p2.update_yaxes(rangemode='tozero', showline=True, linecolor='black', ticks='outside')
fig4_p2.update_xaxes(showline=True, linecolor='black', ticks='outside')

# --- Panel 3: by position, box ---
fig4_p3 = px.box(acc_df_kumar_mfa_pos_avgiter, y='Accuracy', x='Position',
                 color='Aligner', points='all', boxmode='group',
                 color_discrete_map=colorsmap,
                 category_orders={"Aligner": ['Manual', 'Automated']})
fig4_p3.update_traces(marker=dict(size=5, opacity=0.9), jitter=0.3, boxmean=True)
fig4_p3.add_hline(y=1/9, line_dash='dash', line_color='gray',
                  annotation_text='Chance', annotation_position='bottom right')
fig4_p3.update_layout(plot_bgcolor='white', font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
                      margin=dict(l=35, r=8, t=15, b=40))
fig4_p3.update_yaxes(rangemode='tozero', showline=True, linecolor='black', ticks='outside')
fig4_p3.update_xaxes(showline=True, linecolor='black', ticks='outside')

# --- Panel 4: DTW line per patient ---
_df_dtw = per_patient.copy()
_df_dtw["TW_value"] = _df_dtw["Decoding TW"].map(tw_map)
_dash_styles = ["longdash", "dash", "dashdot", "dot"]
_pts_dtw  = _df_dtw["Patient"].unique()
_dash_map = {p: _dash_styles[i % len(_dash_styles)] for i, p in enumerate(_pts_dtw)}

fig4_p4 = go.Figure()
for _pat in _pts_dtw:
    for _ali in ["Manual", "Automated"]:
        _sub = _df_dtw[(_df_dtw["Patient"] == _pat) & (_df_dtw["Aligner"] == _ali)].sort_values("TW_value")
        fig4_p4.add_trace(go.Scatter(
            x=_sub["TW_value"], y=_sub["Accuracy"], mode="lines+markers",
            line=dict(color=colorsmap[_ali], dash=_dash_map[_pat], width=2),
            showlegend=False
        ))
for _ali in ["Manual", "Automated"]:
    fig4_p4.add_trace(go.Scatter(x=[None], y=[None], mode="lines",
                                  line=dict(color=colorsmap[_ali], width=2), name=_ali))
fig4_p4.add_hline(y=1/9, line_dash="dash", line_color="gray",
                  annotation_text="Chance", annotation_position="bottom right")
fig4_p4.update_layout(plot_bgcolor='white', font=dict(size=PLOT_STYLE['font']['size_label'], family=PLOT_STYLE['font']['family']),
                      legend=dict(orientation='h', y=0.02, x=0.01, title_text=''),
                      margin=dict(l=35, r=8, t=15, b=40))
fig4_p4.update_yaxes(title="Decoding Accuracy", rangemode="tozero",
                     showline=True, linecolor="black", ticks="outside")
fig4_p4.update_xaxes(title="Decoding TW (ms)",
                     tickvals=list(tw_map.values()),
                     ticktext=[str(int(v * 1000)) for v in tw_map.values()],
                     showline=True, linecolor="black", ticks="outside")

# --- Assemble ---
panels_fig4 = [
    (fig4_p1, PANEL_DIMS['figure4']['line_by_patient']['width_mm'], PANEL_DIMS['figure4']['line_by_patient']['height_mm']),
    (fig4_p2, PANEL_DIMS['figure4']['by_patient']['width_mm'],      PANEL_DIMS['figure4']['by_patient']['height_mm']),
    (fig4_p3, PANEL_DIMS['figure4']['by_position']['width_mm'],     PANEL_DIMS['figure4']['by_position']['height_mm']),
    (fig4_p4, PANEL_DIMS['figure4']['dtw_line']['width_mm'],        PANEL_DIMS['figure4']['dtw_line']['height_mm']),
]

from IPython.display import SVG, display

_out = "../figures/figure4/figure4_full.svg"
save_full_figure_svg(panels_fig4, 2, 2, _out)
display(SVG(_out))
